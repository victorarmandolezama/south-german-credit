# %% [markdown]
# Las variables categóricas son:
#
# status'
# credit_history'
# purpose'
# savings'
# personal_status_sex'
# other_debtors'
# other_installment_plans'
# housing'
# foreign_worker'
# credit_risk
#
# Las variables continuas son:
#
# duration
# amount
# employment_duration
# installment_rate
# present_residence
# age
# number_credits
# job
# people_liable
# telephon

# %%
from main_functions import create_data, get_statistics, plot_frequencies, plot_boxplot

data = create_data()

data.head()
# Out:
#   status  duration credit_history purpose  amount savings employment_duration  \
# 0      1        18              4       2  1049.0       1                   2
# 1      1         9              4       0  2799.0       1                   3
# 2      2        12              2       9   841.0       2                   4
# 3      1        12              4       0  2122.0       1                   3
# 4      1        12              4       0  2171.0       1                   3
#
#   installment_rate personal_status_sex other_debtors  ... property age  \
# 0                4                   2             1  ...        2  21
# 1                2                   3             1  ...        1  36
# 2                2                   2             1  ...        1  23
# 3                3                   3             1  ...        1  39
# 4                4                   3             1  ...        2  38
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   status                   1000 non-null   category
#  1   duration                 1000 non-null   int64
#  2   credit_history           1000 non-null   category
#  3   purpose                  1000 non-null   category
#  4   amount                   1000 non-null   float64
#  5   savings                  1000 non-null   category
#  6   employment_duration      1000 non-null   category
#  7   installment_rate         1000 non-null   category
#  8   personal_status_sex      1000 non-null   category
#  9   other_debtors            1000 non-null   category
#  10  present_residence        1000 non-null   category
#  11  property                 1000 non-null   category
#  12  age                      1000 non-null   int64
# ...

# %%
categorical_variable_names = [
    'status',
    'credit_history',
    'purpose',
    'savings',
    'personal_status_sex',
    'other_debtors',
    'other_installment_plans',
    'housing',
    'foreign_worker',
    'credit_risk',
    'people_liable',
    'number_credits',
    'telephone',
    'job',
    'employment_duration',
    'installment_rate',
    'present_residence',
]

# Arreglo de variables continuas
continuous_variable_names = [
    'duration',
    'amount',
    'age',
]

estadisticos_continuas, estadisticos_categoricas, frecuencias_relativas = get_statistics(data, continuous_variable_names, categorical_variable_names )

# %%
estadisticos_continuas
# Out:
#           duration       amount         age
# count  1000.000000   1000.00000  1000.00000
# mean     20.903000   3271.24800    35.54200
# std      12.058814   2822.75176    11.35267
# min       4.000000    250.00000    19.00000
# 25%      12.000000   1365.50000    27.00000
# 50%      18.000000   2319.50000    33.00000
# 75%      24.000000   3972.25000    42.00000
# max      72.000000  18424.00000    75.00000

# %%
estadisticos_categoricas
# Out:
#        status credit_history purpose savings personal_status_sex  \
# count    1000           1000    1000    1000                1000
# unique      4              5      10       5                   4
# top         4              2       3       1                   3
# freq      394            530     280     603                 548
#
#        other_debtors other_installment_plans housing foreign_worker  \
# count           1000                    1000    1000           1000
# unique             3                       3       3              2
# top                1                       3       2              2
# freq             907                     814     714            963
#
#        credit_risk people_liable number_credits telephone   job  \
# count         1000          1000           1000      1000  1000
# unique           2             2              4         2     4
# top              1             2              1         1     3
# ...

# %%
frecuencias_relativas
# Out:
# {'status': 4    0.394
#  1    0.274
#  2    0.269
#  3    0.063
#  Name: status, dtype: float64,
#  'credit_history': 2    0.530
#  4    0.293
#  3    0.088
#  1    0.049
#  0    0.040
#  Name: credit_history, dtype: float64,
#  'purpose': 3     0.280
#  0     0.234
#  2     0.181
#  1     0.103
#  9     0.097
#  6     0.050
#  5     0.022
#  10    0.012
#  4     0.012
#  8     0.009
#  Name: purpose, dtype: float64,
#  'savings': 1    0.603
#  5    0.183
#  2    0.103
#  3    0.063
#  4    0.048
#  Name: savings, dtype: float64,
#  'personal_status_sex': 3    0.548
#  2    0.310
#  4    0.092
#  1    0.050
#  Name: personal_status_sex, dtype: float64,
#  'other_debtors': 1    0.907
#  3    0.052
#  2    0.041
#  Name: other_debtors, dtype: float64,
#  'other_installment_plans': 3    0.814
#  1    0.139
#  2    0.047
#  Name: other_installment_plans, dtype: float64,
#  'housing': 2    0.714
#  1    0.179
#  3    0.107
#  Name: housing, dtype: float64,
#  'foreign_worker': 2    0.963
# ...

# %%
plot_frequencies(data, categorical_variable_names)

# %%
data.duration.hist(figsize=(10, 5), grid=False, bins=30)
# Out:
# <AxesSubplot: >

# %%
plot_boxplot(data, 'duration')

# %%
data.amount.hist(figsize=(10, 5), grid=False, bins=50)
# Out:
# <AxesSubplot: >

# %%
plot_boxplot(data, 'amount')

# %%
data.age.hist(figsize=(10, 5), grid=False, bins=30)
# Out:
# <AxesSubplot: >

# %%
plot_boxplot(data, 'age')

# %%
registros_credit_risk_0 = data[data['credit_risk'] == '0']
registros_credit_risk_1 = data[data['credit_risk'] == '1']

# %%
estadisticos_continuas, estadisticos_categoricas, frecuencias_relativas = get_statistics(registros_credit_risk_0, continuous_variable_names, categorical_variable_names )

# %%
estadisticos_categoricas
# Out:
#        status credit_history purpose savings personal_status_sex  \
# count     300            300     300     300                 300
# unique      4              5      10       5                   4
# top         1              2       0       1                   3
# freq      135            169      89     217                 146
#
#        other_debtors other_installment_plans housing foreign_worker  \
# count            300                     300     300            300
# unique             3                       3       3              2
# top                1                       3       2              2
# freq             272                     224     186            296
#
#        credit_risk people_liable number_credits telephone  job  \
# count          300           300            300       300  300
# unique           1             2              4         2    4
# top              0             2              1         1    3
# ...

# %%
estadisticos_continuas
# Out:
#          duration        amount         age
# count  300.000000    300.000000  300.000000
# mean    24.860000   3938.126667   33.960000
# std     13.282639   3535.818955   11.225199
# min      6.000000    433.000000   19.000000
# 25%     12.000000   1352.500000   25.000000
# 50%     24.000000   2574.500000   31.000000
# 75%     36.000000   5141.500000   40.000000
# max     72.000000  18424.000000   74.000000

# %%
frecuencias_relativas
# Out:
# {'status': 1    0.450000
#  2    0.350000
#  4    0.153333
#  3    0.046667
#  Name: status, dtype: float64,
#  'credit_history': 2    0.563333
#  4    0.166667
#  1    0.093333
#  3    0.093333
#  0    0.083333
#  Name: credit_history, dtype: float64,
#  'purpose': 0     0.296667
#  3     0.206667
#  2     0.193333
#  9     0.113333
#  6     0.073333
#  1     0.056667
#  5     0.026667
#  10    0.016667
#  4     0.013333
#  8     0.003333
#  Name: purpose, dtype: float64,
#  'savings': 1    0.723333
#  2    0.113333
#  5    0.106667
#  3    0.036667
#  4    0.020000
#  Name: savings, dtype: float64,
#  'personal_status_sex': 3    0.486667
#  2    0.363333
#  4    0.083333
#  1    0.066667
#  Name: personal_status_sex, dtype: float64,
#  'other_debtors': 1    0.906667
#  2    0.060000
#  3    0.033333
#  Name: other_debtors, dtype: float64,
#  'other_installment_plans': 3    0.746667
#  1    0.190000
#  2    0.063333
#  Name: other_installment_plans, dtype: float64,
# ...

# %%
plot_frequencies(registros_credit_risk_0, categorical_variable_names)

# %%
registros_credit_risk_0.duration.hist(figsize=(10, 5), grid=False, bins=30)
# Out:
# <AxesSubplot: >

# %%
registros_credit_risk_0.amount.hist(figsize=(10, 5), grid=False, bins=50)
# Out:
# <AxesSubplot: >

# %%
registros_credit_risk_0.age.hist(figsize=(10, 5), grid=False, bins=30)
# Out:
# <AxesSubplot: >

# %%
estadisticos_continuas, estadisticos_categoricas, frecuencias_relativas = get_statistics(registros_credit_risk_1, continuous_variable_names, categorical_variable_names )

# %%
estadisticos_categoricas
# Out:
#        status credit_history purpose savings personal_status_sex  \
# count     700            700     700     700                 700
# unique      4              5      10       5                   4
# top         4              2       3       1                   3
# freq      348            361     218     386                 402
#
#        other_debtors other_installment_plans housing foreign_worker  \
# count            700                     700     700            700
# unique             3                       3       3              2
# top                1                       3       2              2
# freq             635                     590     528            667
#
#        credit_risk people_liable number_credits telephone  job  \
# count          700           700            700       700  700
# unique           1             2              4         2    4
# top              1             2              1         1    3
# ...

# %%
estadisticos_continuas
# Out:
#          duration        amount         age
# count  700.000000    700.000000  700.000000
# mean    19.207143   2985.442857   36.220000
# std     11.079564   2401.495579   11.347428
# min      4.000000    250.000000   19.000000
# 25%     12.000000   1375.500000   27.000000
# 50%     18.000000   2244.000000   34.000000
# 75%     24.000000   3634.750000   42.000000
# max     60.000000  15857.000000   75.000000

# %%
frecuencias_relativas
# Out:
# {'status': 4    0.497143
#  2    0.234286
#  1    0.198571
#  3    0.070000
#  Name: status, dtype: float64,
#  'credit_history': 2    0.515714
#  4    0.347143
#  3    0.085714
#  1    0.030000
#  0    0.021429
#  Name: credit_history, dtype: float64,
#  'purpose': 3     0.311429
#  0     0.207143
#  2     0.175714
#  1     0.122857
#  9     0.090000
#  6     0.040000
#  5     0.020000
#  4     0.011429
#  8     0.011429
#  10    0.010000
#  Name: purpose, dtype: float64,
#  'savings': 1    0.551429
#  5    0.215714
#  2    0.098571
#  3    0.074286
#  4    0.060000
#  Name: savings, dtype: float64,
#  'personal_status_sex': 3    0.574286
#  2    0.287143
#  4    0.095714
#  1    0.042857
#  Name: personal_status_sex, dtype: float64,
#  'other_debtors': 1    0.907143
#  3    0.060000
#  2    0.032857
#  Name: other_debtors, dtype: float64,
#  'other_installment_plans': 3    0.842857
#  1    0.117143
#  2    0.040000
#  Name: other_installment_plans, dtype: float64,
# ...

# %%
plot_frequencies(registros_credit_risk_1, categorical_variable_names)

# %%
registros_credit_risk_1.duration.hist(figsize=(10, 5), grid=False, bins=30)
# Out:
# <AxesSubplot: >

# %%
registros_credit_risk_1.amount.hist(figsize=(10, 5), grid=False, bins=50)
# Out:
# <AxesSubplot: >

# %%
registros_credit_risk_1.age.hist(figsize=(10, 5), grid=False, bins=30)
# Out:
# <AxesSubplot: >

# %%
registros_credit_risk_0.columns
# Out:
# Index(['status', 'duration', 'credit_history', 'purpose', 'amount', 'savings',
#        'employment_duration', 'installment_rate', 'personal_status_sex',
#        'other_debtors', 'present_residence', 'property', 'age',
#        'other_installment_plans', 'housing', 'number_credits', 'job',
#        'people_liable', 'telephone', 'foreign_worker', 'credit_risk'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=data, x='credit_history', y='amount', hue='status', ci=None, palette='pastel')
plt.title('Promedio de monto de crédito solicitado por la combinación de estatus e historial de crédito (full data)')
plt.xlabel('Historial de crédito')
plt.ylabel('Promedio de monto solicitado')
plt.legend(title='Estatus')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# /var/folders/l6/bfk83gm94_x23ld0qfdlhyhh0000gs/T/ipykernel_43650/3752490779.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data, x='credit_history', y='amount', hue='status', ci=None, palette='pastel')

# %%
data_filtered = data[(data['credit_history'] == "0") & (data["status"] == "2")]
sns.countplot(data=data_filtered, x="credit_risk")
# Out:
# <AxesSubplot: xlabel='credit_risk', ylabel='count'>

# %%
data_filtered = data[(data['credit_history'] == "1") & (data["status"] == "2")]
sns.countplot(data=data_filtered, x="credit_risk")
# Out:
# <AxesSubplot: xlabel='credit_risk', ylabel='count'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=data, x='credit_risk', y='amount', hue='status', ci=None, palette='pastel')
plt.title('Promedio de monto de crédito solicitado por la combinación de estatus y riesgo crediticio')
plt.xlabel('Es cliente de riesgo')
plt.ylabel('Promedio de monto solicitado')
plt.legend(title='Estatus')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# /var/folders/l6/bfk83gm94_x23ld0qfdlhyhh0000gs/T/ipykernel_43650/2215961850.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data, x='credit_risk', y='amount', hue='status', ci=None, palette='pastel')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=data, x='purpose', y='amount', hue='credit_history', ci=None, palette='pastel')
plt.title('Promedio de monto de crédito solicitado por la combinación de estatus e historial de crédito')
plt.xlabel('Es cliente de riesgo')
plt.ylabel('Promedio de monto solicitado')
plt.legend(title='Historial de crédito')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# /var/folders/l6/bfk83gm94_x23ld0qfdlhyhh0000gs/T/ipykernel_43650/3887472807.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data, x='purpose', y='amount', hue='credit_history', ci=None, palette='pastel')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=data, x='purpose', y='amount', hue='status', ci=None, palette='pastel')
plt.title('Promedio de monto de crédito solicitado por la combinación de estatus e historial de crédito')
plt.xlabel('Es cliente de riesgo')
plt.ylabel('Promedio de monto solicitado')
plt.legend(title='Estatus')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# /var/folders/l6/bfk83gm94_x23ld0qfdlhyhh0000gs/T/ipykernel_43650/3038599364.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data, x='purpose', y='amount', hue='status', ci=None, palette='pastel')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=data[(data['credit_risk'] == "0")], x='credit_history', y='amount', hue='status', ci=None, palette='pastel')
plt.title('Promedio de monto de crédito solicitado por la combinación de estatus e historial de crédito (bad credit)')
plt.xlabel('Historial de crédito')
plt.ylabel('Promedio de monto solicitado')
plt.legend(title='Estatus')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# /var/folders/l6/bfk83gm94_x23ld0qfdlhyhh0000gs/T/ipykernel_43650/189943346.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data[(data['credit_risk'] == "0")], x='credit_history', y='amount', hue='status', ci=None, palette='pastel')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=data[(data['credit_risk'] == "0")], x='credit_history', y='amount', hue='status', ci=None, palette='pastel')
plt.title('Promedio de monto de crédito solicitado por la combinación de estatus e historial de crédito (good credit)')
plt.xlabel('Historial de crédito')
plt.ylabel('Promedio de monto solicitado')
plt.legend(title='Estatus')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# /var/folders/l6/bfk83gm94_x23ld0qfdlhyhh0000gs/T/ipykernel_43650/3658444900.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data[(data['credit_risk'] == "0")], x='credit_history', y='amount', hue='status', ci=None, palette='pastel')

# %%
sns.violinplot(data, x="credit_history", y="amount", hue="credit_risk", split=True, palette='pastel')
# Out:
# <AxesSubplot: xlabel='credit_history', ylabel='amount'>

# %%
sns.violinplot(data, x="status", y="amount", hue="credit_risk", split=True, palette='pastel')
# Out:
# <AxesSubplot: xlabel='status', ylabel='amount'>

# %%
plt.figure(figsize=(15, 10))
sns.violinplot(data, x="credit_history", y="amount", hue="status", palette='pastel', width=0.9)
plt.title('Gráfico de violín de historial de crédito por monto de crédito solicitado y estatus')
plt.xlabel('Historial de crédito')
plt.ylabel('Promedio de monto solicitado')
plt.legend(title='Estatus')
plt.show()

# %%
sns.boxplot(data, x='credit_risk', y='amount', palette='pastel')
# Out:
# <AxesSubplot: xlabel='credit_risk', ylabel='amount'>

# %%
sns.boxplot(data, x='credit_risk', y='age', palette='pastel')
# Out:
# <AxesSubplot: xlabel='credit_risk', ylabel='age'>

# %%
sns.boxplot(data, x='credit_risk', y='duration', palette='pastel')
# Out:
# <AxesSubplot: xlabel='credit_risk', ylabel='duration'>

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data[(data['credit_risk'] == "1")], x='purpose', hue='credit_history', palette='pastel')
plt.title('Frecuencias de la combinación de estatus e historial de crédito (good)')
plt.xlabel('Propósito')
plt.legend(title='Historial de crédito')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data[(data['credit_risk'] == "0")], x='purpose', hue='credit_history',palette='pastel')
plt.title('Frecuencias de la combinación de estatus e historial de crédito (bad)')
plt.xlabel('Propósito')
plt.legend(title='Historial de crédito')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
